# %% [markdown]
# <a href="https://colab.research.google.com/github/19K41A0565/NNDL/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Import libraries
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
import math

# %%
#@title Load the data
data=pd.read_excel('/content/drive/MyDrive/Assignment1.xlsx')
data.head()
# Out:
#        X      Y
# 0   75.1  577.8
# 1   74.3  577.0
# 2   88.7  570.9
# 3  114.6  578.6
# 4   98.5  572.4

# %%
#@title Data Normalization
maxX = np.max(data['X'])
minX = np.min(data['X'])
maxY = np.max(data['Y'])
minY = np.min(data['Y'])
data['X'] = (data['X'] - minX) / (maxX - minX)
data['Y'] = (data['Y'] - minY) / (maxY - minY)

# %%
#@title Split the Data
x = data['X']
y = data['Y']
trainX, testX, trainY, testY = train_test_split(x, y, test_size=0.1, random_state=10)

# %%
#@title BGD Optimisation Algorithm
m = np.random.uniform(-50, 50)
c = np.random.uniform(-50, 50)
eta = 0.5
epochs = 500

for _ in range(epochs):
    
    gradM = -sum([(trainY.iloc[i] - m * trainX.iloc[i] - c) * trainX.iloc[i] for i in range(trainX.shape[0])])
    gradM /= trainX.shape[0]
    
    gradC = -sum([(trainY.iloc[i] - m * trainX.iloc[i] - c) for i in range(trainX.shape[0])])
    gradC /= trainX.shape[0]
    
    c += - eta * gradC
    m += - eta * gradM

print(f'm = {m}\nc = {c}')
# Out:
# m = -0.044539683638794535
# c = 0.6655390486831114

# %%
#@title Model prediction and error metric calculations
train_pred = [m * trainX.iloc[i] + c for i in range(trainX.shape[0])]
test_pred = [m * testX.iloc[i] + c for i in range(testX.shape[0])]

train_pred = [i * (maxY - minY) + minY for i in train_pred]
test_pred = [i * (maxY - minY) + minY for i in test_pred]
trainY = [i * (maxY - minY) + minY for i in trainY]
testY = [i * (maxY - minY) + minY for i in testY]

training_MAE = sum([abs(train_pred[i] - trainY[i]) for i in range(len(trainY))]) / len(trainY)
training_MSE = sum([(train_pred[i] - trainY[i]) ** 2 for i in range(len(trainY))]) / len(trainY)
training_RMSE = training_MSE ** 0.5
print('Training Error :')
print(f'MAE : {training_MAE}')
print(f'MSE : {training_MSE}')
print(f'RMSE : {training_RMSE}')

testing_MAE = sum([abs(test_pred[i] - testY[i]) for i in range(len(testY))]) / len(testY)
testing_MSE = sum([(test_pred[i] - testY[i]) ** 2 for i in range(len(testY))]) / len(testY)
testing_RMSE = testing_MSE ** 0.5
print('Testing Error :')
print(f'MAE : {testing_MAE}')
print(f'MSE : {testing_MSE}')
print(f'RMSE : {testing_RMSE}')
# Out:
# Training Error :
# MAE : 23.180573448314448
# MSE : 1177.645125127756
# RMSE : 34.31683442754818
# Testing Error :
# MAE : 52.77082279949516
# MSE : 4217.742505659293
# RMSE : 64.94414912568563

# %%
pd.DataFrame({'Actual' : trainY, 'Predicted':train_pred})
# Out:
#     Actual   Predicted
# 0    570.9  517.595888
# 1    578.6  514.165092
# 2    512.8  517.476671
# 3    510.2  517.026297
# 4    510.0  518.496638
# 5    506.4  516.178532
# 6    577.0  519.503358
# 7    510.9  515.383753
# 8    503.9  519.556343
# 9    508.6  514.800915
# 10   531.7  514.138599
# 11   505.2  514.006136
# 12   493.0  515.926852
# 13   510.8  513.449791
# 14   504.3  518.178726
# 15   502.8  519.569590
# 16   496.4  519.569590
# 17   513.4  519.251678
# 18   522.0  516.363981
# 19   406.7  515.171812
# 20   512.8  519.291417
# 21   506.3  520.576310
# 22   510.2  519.026491
# 23   577.8  519.397387
# 24   506.2  520.642541
# 25   572.4  516.297749
# 26   507.1  517.357455

# %%
#@title Model Deployment
x = float(input('Enter the pressure of liquid nitrogen : '))
x = (x - minX) / (maxX - minX)
prediction = m * x + c
prediction = (prediction * (maxY - minY)) + minY
print('Predicted Weight :', prediction)
# Out:
# Enter the pressure of liquid nitrogen : 234.9
# Predicted Weight : 498.229771839842
